# %% [markdown]
# #  Opening the csv file using pandas. Checking characteristics of the dataset. What is the shape of the dataset, what are the statistics of the columns, are there any NaNs?

# %%
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# #  Clean the dataset (if you find any NaNs)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# #  Which game has the highest global sales? What is its platform?

# %%
df.sort_values('Global_Sales', ascending = False)
# Out:
#         Rank                                             Name Platform  \
# 0          1                                       Wii Sports      Wii
# 1          2                                Super Mario Bros.      NES
# 2          3                                   Mario Kart Wii      Wii
# 3          4                                Wii Sports Resort      Wii
# 4          5                         Pokemon Red/Pokemon Blue       GB
# ...      ...                                              ...      ...
# 16183  16186                      Sakura-Sou no Pet na Kanojo      PSP
# 16184  16187  Fatal Fury: Battle Archives Volume 2 (JP sales)      PS2
# 16185  16188           Tantei Jinguuji Saburo: Hai to Diamond      PSP
# 16186  16189                                      BattleForge       PC
# 16597  16600                                 Spirits & Spells      GBA
#
#          Year         Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# #  Which are the platforms in the dataset?

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# #  Which are the top ten selling games for PS4 (Global sales)? Is this the same for Europe and Japan sales combined?

# %%
ps4 = df[df['Platform'] == 'PS4'].sort_values('Global_Sales', ascending = False)
ps4.head(10)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 44     45              Grand Theft Auto V      PS4  2014.0        Action
# 77     78                         FIFA 16      PS4  2015.0        Sports
# 92     93    Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 93     94  Call of Duty: Advanced Warfare      PS4  2014.0       Shooter
# 109   110                       Fallout 4      PS4  2015.0  Role-Playing
# 124   125                         FIFA 15      PS4  2014.0        Sports
# 154   155                         Destiny      PS4  2014.0       Shooter
# 221   222                         FIFA 17      PS4  2016.0        Sports
# 236   237                  The Last of Us      PS4  2014.0        Action
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33                    Activision      5.77      5.81      0.35         2.31
# ...

# %% [markdown]
# #  Is this the same for Europe and Japan sales combined?

# %%
df['eu_jp_sales'] = df['EU_Sales'] + df['JP_Sales']
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
ps4 = df[df['Platform'] == 'PS4'].sort_values('eu_jp_sales', ascending = False)
ps4.head(10)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 44     45              Grand Theft Auto V      PS4  2014.0        Action
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 77     78                         FIFA 16      PS4  2015.0        Sports
# 124   125                         FIFA 15      PS4  2014.0        Sports
# 221   222                         FIFA 17      PS4  2016.0        Sports
# 92     93    Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 93     94  Call of Duty: Advanced Warfare      PS4  2014.0       Shooter
# 109   110                       Fallout 4      PS4  2015.0  Role-Playing
# 271   272      Uncharted 4: A Thief's End      PS4  2016.0       Shooter
# 295   296                       Far Cry 4      PS4  2014.0       Shooter
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 44          Take-Two Interactive      3.80      5.81      0.36         2.02
# ...

# %% [markdown]
# #  How many games were released for XOne in 2016? Which was the top selling in Europe?

# %%
x_box_one = df[(df['Platform'] == 'XOne') & (df['Year'] == 2016) ]                # for OR use |
x_box_one.head()
# Out:
#       Rank                       Name Platform    Year    Genre  \
# 845    847  Tom Clancy's The Division     XOne  2016.0  Shooter
# 1224  1226                    FIFA 17     XOne  2016.0   Sports
# 2434  2436            Far Cry: Primal     XOne  2016.0   Action
# 2444  2446                  Overwatch     XOne  2016.0  Shooter
# 2505  2507              Madden NFL 17     XOne  2016.0   Sports
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 845           Ubisoft      1.20      0.62       0.0         0.18
# 1224  Electronic Arts      0.17      1.26       0.0         0.10
# 2434          Ubisoft      0.46      0.32       0.0         0.07
# 2444       Activision      0.52      0.25       0.0         0.08
# 2505  Electronic Arts      0.72      0.02       0.0         0.09
#
#       Global_Sales  eu_jp_sales
# 845           2.01         0.62
# 1224          1.53         1.26
# 2434          0.85         0.32
# 2444          0.85         0.25
# ...

# %%
x_box_one.sort_values('EU_Sales', ascending = False)
# Out:
#         Rank                                               Name Platform  \
# 1224    1226                                            FIFA 17     XOne
# 845      847                          Tom Clancy's The Division     XOne
# 2434    2436                                    Far Cry: Primal     XOne
# 2444    2446                                          Overwatch     XOne
# 2991    2993                                        Doom (2016)     XOne
# 5015    5017                                    Forza Horizon 3     XOne
# 3927    3929                                      Quantum Break     XOne
# 4430    4432               Plants vs. Zombies: Garden Warfare 2     XOne
# 4820    4822                                    EA Sports UFC 2     XOne
# 5595    5597                             LEGO Marvel's Avengers     XOne
# 6910    6912                  Lego Star Wars: The Force Awakens     XOne
# 9711    9713                                      Rocket League     XOne
# ...

# %% [markdown]
# #  Replace where XOne with ‘X Box One’

# %%
df['Platform'].replace('XOne', 'X Box One', inplace = True)
df.tail(30)
# Out:
#         Rank                                               Name   Platform  \
# 16568  16571                                        XI Coliseum        PSP
# 16569  16572                                 Resident Evil 4 HD  X Box One
# 16570  16573                      Farming 2017 - The Simulation        PS4
# 16571  16574         Grisaia no Kajitsu: La Fruit de la Grisaia        PSP
# 16572  16575                   Scarlett: Nichijou no Kyoukaisen        PS2
# 16573  16576                                Mini Desktop Racing        Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...        Wii
# 16575  16578                              Neo Angelique Special        PSP
# 16576  16579                                  Rugby Challenge 3  X Box One
# 16577  16580                                          Damnation         PC
# 16578  16581                      Outdoors Unleashed: Africa 3D        3DS
# ...

# %% [markdown]
# #  How many PC games have higher sales than 3 million global sales?

# %%
pc_games = df[       (df['Platform'] == 'PC') & (df['Global_Sales'] > 3)       ]
pc_games
# Out:
#      Rank                                    Name Platform    Year  \
# 83     84                              The Sims 3       PC  2009.0
# 137   138                       World of Warcraft       PC  2004.0
# 181   182                              Diablo III       PC  2012.0
# 194   195              Microsoft Flight Simulator       PC  1996.0
# 217   218          StarCraft II: Wings of Liberty       PC  2010.0
# 267   268          Warcraft II: Tides of Darkness       PC  1995.0
# 281   282                               Half-Life       PC  1997.0
# 288   289  World of Warcraft: The Burning Crusade       PC  2007.0
# 310   311             The Elder Scrolls V: Skyrim       PC  2011.0
# 328   329                     The Sims: Unleashed       PC  2002.0
# 353   354                  Doom II: Hell on Earth       PC  1994.0
# 456   457                      The Sims: Vacation       PC  2002.0
#
#             Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
len(pc_games)
# Out:
# 12

# %% [markdown]
# #  Which action game has the highest global sales?

# %%
df[df['Genre'] == 'Action']
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 38        39                               Grand Theft Auto III      PS2
# ...      ...                                                ...      ...
# 16564  16567      Original Frisbee Disc Sports: Ultimate & Golf       DS
# 16567  16570  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# 16582  16585                                    Planet Monsters      GBA
# 16583  16586                                     Carmageddon 64      N64
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year   Genre                  Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df[df['Genre'] == 'Action'].sort_values('Global_Sales', ascending = False)
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 38        39                               Grand Theft Auto III      PS2
# ...      ...                                                ...      ...
# 16167  16170                                         Order Up!!      3DS
# 16158  16161                      Monkey Madness: Island Escape       DS
# 16151  16154                     SoulCalibur Legends (JP sales)      Wii
# 16147  16150                           Chokkan! Asonde Relaxuma       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year   Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# #  In which year the most games were released?

# %%
df.groupby('Year').count().sort_values(['Name'], ascending = False)
# Out:
#         Rank  Name  Platform  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Year
# 2009.0  1431  1431      1431   1431       1431      1431      1431      1431
# 2008.0  1428  1428      1428   1428       1428      1428      1428      1428
# 2010.0  1257  1257      1257   1257       1257      1257      1257      1257
# 2007.0  1201  1201      1201   1201       1201      1201      1201      1201
# 2011.0  1136  1136      1136   1136       1136      1136      1136      1136
# 2006.0  1008  1008      1008   1008       1008      1008      1008      1008
# 2005.0   936   936       936    936        936       936       936       936
# 2002.0   829   829       829    829        829       829       829       829
# 2003.0   775   775       775    775        775       775       775       775
# 2004.0   744   744       744    744        744       744       744       744
# 2012.0   655   655       655    655        655       655       655       655
# ...

# %%
df.groupby('Year').count().plot.bar(figsize=(18,6))
None

# %% [markdown]
# #  Which platform had the most releases that year?

# %%
df_2009 = df[df['Year'] == 2009]
df_2009.head()
# Out:
#     Rank                                  Name Platform    Year     Genre  \
# 3      4                     Wii Sports Resort      Wii  2009.0    Sports
# 8      9             New Super Mario Bros. Wii      Wii  2009.0  Platform
# 14    15                          Wii Fit Plus      Wii  2009.0    Sports
# 36    37        Call of Duty: Modern Warfare 2     X360  2009.0   Shooter
# 45    46  Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0    Action
#
#      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 3     Nintendo     15.75     11.01      3.28         2.96         33.00
# 8     Nintendo     14.59      7.06      4.70         2.26         28.62
# 14    Nintendo      9.09      8.59      2.53         1.79         22.00
# 36  Activision      8.52      3.63      0.08         1.29         13.51
# 45    Nintendo      4.40      2.77      3.96         0.77         11.90
#
#     eu_jp_sales
# 3         14.29
# 8         11.76
# 14        11.12
# 36         3.71
# ...

# %%
df_2009.groupby('Platform').count().sort_values(['Name'], ascending = False)
# Out:
#           Rank  Name  Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# DS         405   405   405    405        405       405       405       405
# Wii        325   325   325    325        325       325       325       325
# X360       173   173   173    173        173       173       173       173
# PS3        162   162   162    162        162       162       162       162
# PSP        161   161   161    161        161       161       161       161
# PC         109   109   109    109        109       109       109       109
# PS2         96    96    96     96         96        96        96        96
#
#           Other_Sales  Global_Sales  eu_jp_sales
# Platform
# DS                405           405          405
# Wii               325           325          325
# X360              173           173          173
# PS3               162           162          162
# PSP               161           161          161
# PC                109           109          109
# ...

# %% [markdown]
# #  Which are the top 5 selling platforms (games global sales) of all time? Plot your results in a graph

# %%
df.groupby('Platform').sum().sort_values('Global_Sales', ascending=False).head(5)['Global_Sales'].plot.bar(rot = 45)
None

# %% [markdown]
# #  Which are the top three publishers in EU game sales? Use a pie plot to show their contribution. How is it compared with their global sales? Use plots to show your results.

# %%
df.groupby('Publisher').sum().sort_values('EU_Sales', ascending=False)
# Out:
#                                 Rank       Year  NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo                     2646098  1394666.0    815.75    418.30    454.99
# Electronic Arts              7102442  2686562.0    584.22    367.38     13.98
# Activision                   6324706  1938979.0    426.01    213.72      6.54
# Sony Computer Entertainment  4098421  1367034.0    265.22    187.55     74.10
# Ubisoft                      6945872  1843194.0    252.81    163.03      7.33
# ...                              ...        ...       ...       ...       ...
# Epoch                          70061    13962.0      0.00      0.00      0.99
# NEC                            30390     5987.0      0.00      0.00      0.43
# NCS                            28722     5991.0      0.00      0.00      0.40
# Imadio                          9183     1997.0      0.00      0.00      0.14
# Fields                         14145     2012.0      0.00      0.00      0.03
#
# ...

# %%
df.groupby('Publisher').sum().sort_values('EU_Sales', ascending=False).head(3)['EU_Sales'].plot.pie(figsize=(8,8))
None

# %%
df.groupby('Publisher').sum().sort_values('Global_Sales', ascending=False)
# Out:
#                                 Rank       Year  NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo                     2646098  1394666.0    815.75    418.30    454.99
# Electronic Arts              7102442  2686562.0    584.22    367.38     13.98
# Activision                   6324706  1938979.0    426.01    213.72      6.54
# Sony Computer Entertainment  4098421  1367034.0    265.22    187.55     74.10
# Ubisoft                      6945872  1843194.0    252.81    163.03      7.33
# ...                              ...        ...       ...       ...       ...
# Epic Games                     16263     2016.0      0.01      0.00      0.00
# Paradox Development            16347     2016.0      0.00      0.01      0.00
# Rain Games                     16568     2015.0      0.00      0.01      0.00
# Ascaron Entertainment          16292     2012.0      0.00      0.01      0.00
# Commseed                       16460     2008.0      0.00      0.00      0.01
#
# ...

# %%
df.groupby('Publisher').sum().sort_values('Global_Sales', ascending=False).head(3)['Global_Sales'].plot.pie(figsize=(8,8))
None

# %% [markdown]
# #  Which are the top 5 most mentioned genres of all time? Is this different in 2014, 2015, 2016?

# %%
top_genres = df.groupby('Genre').count().sort_values(['Name'], ascending = False)
top_genres.head()
# Out:
#               Rank  Name  Platform  Year  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action        3251  3251      3251  3251       3251      3251      3251
# Sports        2304  2304      2304  2304       2304      2304      2304
# Misc          1686  1686      1686  1686       1686      1686      1686
# Role-Playing  1470  1470      1470  1470       1470      1470      1470
# Shooter       1282  1282      1282  1282       1282      1282      1282
#
#               JP_Sales  Other_Sales  Global_Sales  eu_jp_sales
# Genre
# Action            3251         3251          3251         3251
# Sports            2304         2304          2304         2304
# Misc              1686         1686          1686         1686
# Role-Playing      1470         1470          1470         1470
# Shooter           1282         1282          1282         1282

# %%
top_genres.head()['Name'].plot.bar(rot = 45)
None

# %%
df_2014 = df[df['Year'] == 2014]
df_2014.head()
# Out:
#      Rank                                       Name Platform    Year  \
# 44     45                         Grand Theft Auto V      PS4  2014.0
# 49     50  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014.0
# 93     94             Call of Duty: Advanced Warfare      PS4  2014.0
# 97     98        Super Smash Bros. for Wii U and 3DS      3DS  2014.0
# 108   109                               Mario Kart 8     WiiU  2014.0
#
#             Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 44         Action  Take-Two Interactive      3.80      5.81      0.36
# 49   Role-Playing              Nintendo      4.23      3.37      3.08
# 93        Shooter            Activision      2.80      3.30      0.14
# 97       Fighting              Nintendo      3.24      1.35      2.42
# 108        Racing              Nintendo      3.13      2.07      1.27
#
#      Other_Sales  Global_Sales  eu_jp_sales
# 44          2.02         11.98         6.17
# ...

# %%
top_genres_2014 = df_2014.groupby('Genre').count().sort_values(['Name'], ascending = False).head()
top_genres_2014
# Out:
#               Rank  Name  Platform  Year  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action         186   186       186   186        186       186       186
# Role-Playing    90    90        90    90         90        90        90
# Adventure       75    75        75    75         75        75        75
# Sports          55    55        55    55         55        55        55
# Shooter         47    47        47    47         47        47        47
#
#               JP_Sales  Other_Sales  Global_Sales  eu_jp_sales
# Genre
# Action             186          186           186          186
# Role-Playing        90           90            90           90
# Adventure           75           75            75           75
# Sports              55           55            55           55
# Shooter             47           47            47           47

# %%
top_genres_2014['Name'].plot.bar(rot = 45)
None

# %%
df_2015 = df[df['Year'] == 2015]
df_2015.head()
# Out:
#      Rank                          Name   Platform    Year         Genre  \
# 33     34     Call of Duty: Black Ops 3        PS4  2015.0       Shooter
# 77     78                       FIFA 16        PS4  2015.0        Sports
# 92     93  Star Wars Battlefront (2015)        PS4  2015.0       Shooter
# 101   102     Call of Duty: Black Ops 3  X Box One  2015.0       Shooter
# 109   110                     Fallout 4        PS4  2015.0  Role-Playing
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33           Activision      5.77      5.81      0.35         2.31
# 77      Electronic Arts      1.11      6.06      0.06         1.26
# 92      Electronic Arts      2.93      3.29      0.22         1.23
# 101          Activision      4.52      2.09      0.01         0.67
# 109  Bethesda Softworks      2.47      3.15      0.24         1.10
#
#      Global_Sales  eu_jp_sales
# 33          14.24         6.16
# 77           8.49         6.12
# ...

# %%
top_genres_2015 = df_2015.groupby('Genre').count().sort_values(['Name'], ascending = False).head()
top_genres_2015
# Out:
#               Rank  Name  Platform  Year  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action         255   255       255   255        255       255       255
# Role-Playing    78    78        78    78         78        78        78
# Sports          62    62        62    62         62        62        62
# Adventure       54    54        54    54         54        54        54
# Misc            39    39        39    39         39        39        39
#
#               JP_Sales  Other_Sales  Global_Sales  eu_jp_sales
# Genre
# Action             255          255           255          255
# Role-Playing        78           78            78           78
# Sports              62           62            62           62
# Adventure           54           54            54           54
# Misc                39           39            39           39

# %%
top_genres_2015['Name'].plot.bar(rot = 45)
None

# %%
df_2016 = df[df['Year'] == 2016]
df_2016.head()
# Out:
#      Rank                        Name   Platform    Year    Genre  \
# 221   222                     FIFA 17        PS4  2016.0   Sports
# 271   272  Uncharted 4: A Thief's End        PS4  2016.0  Shooter
# 351   352   Tom Clancy's The Division        PS4  2016.0  Shooter
# 770   772             Far Cry: Primal        PS4  2016.0   Action
# 845   847   Tom Clancy's The Division  X Box One  2016.0  Shooter
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 221              Electronic Arts      0.28      3.75      0.06         0.69
# 271  Sony Computer Entertainment      1.30      2.07      0.18         0.65
# 351                      Ubisoft      1.28      1.61      0.15         0.57
# 770                      Ubisoft      0.59      1.16      0.06         0.33
# 845                      Ubisoft      1.20      0.62      0.00         0.18
#
#      Global_Sales  eu_jp_sales
# 221          4.77         3.81
# 271          4.20         2.25
# ...

# %%
top_genres_2016 = df_2016.groupby('Genre').count().sort_values(['Name'], ascending = False).head()
top_genres_2016
# Out:
#               Rank  Name  Platform  Year  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action         118   118       118   118        118       118       118
# Role-Playing    40    40        40    40         40        40        40
# Sports          38    38        38    38         38        38        38
# Adventure       33    33        33    33         33        33        33
# Shooter         32    32        32    32         32        32        32
#
#               JP_Sales  Other_Sales  Global_Sales  eu_jp_sales
# Genre
# Action             118          118           118          118
# Role-Playing        40           40            40           40
# Sports              38           38            38           38
# Adventure           33           33            33           33
# Shooter             32           32            32           32

# %%
top_genres_2016['Name'].plot.bar(rot = 45)
None
